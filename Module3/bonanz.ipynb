# %%
# Import modules from the libraries required in this assignment.
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
# Make the connection to the CSV source file.
bona_csv = Path(r"C:\Users\admin\Desktop\FinTech\FinTech2022_Module3_Financial Analysis_Pandas\04_Banking_Bonanza\Resources\lending_rates.csv")

# %%
# Make Pandas read the CSV file.
# Create data structure of Pandas container via dataframes.
bon_df = pd.read_csv(bona_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
# Sample the dataset.
bon_df
# Out:
#             Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# Date
# 2019-01-01          1.49        2.70         4.69            7.77
# 2019-01-02          1.84        2.82         4.64            8.06
# 2019-01-03          1.69        2.92         4.61            8.08
# 2019-01-04          1.57        3.01         4.70            8.04
# 2019-01-05          1.30        2.94         5.05            7.95
# ...                  ...         ...          ...             ...
# 2020-12-26          1.17        3.26         4.85            7.27
# 2020-12-27          1.20        3.26         4.86            7.35
# 2020-12-28          1.21        3.23         4.86            7.49
# 2020-12-29          1.20        3.19         4.84            7.58
# 2020-12-30          1.21        3.17         4.82            7.67
#
# [730 rows x 4 columns]

# %% [markdown]
# # C.P.A.

# %%
# Make index be the date.
# Search for "dirty data"
bon_df.isnull().sum()
# Out:
# Funding Rate      0
# Prime Rate        0
# Retail Rate       0
# Sub-prime Rate    0
# dtype: int64

# %%
bon_df.duplicated().sum()
# Out:
# 0

# %%
bon_df.dtypes
# Out:
# Funding Rate      float64
# Prime Rate        float64
# Retail Rate       float64
# Sub-prime Rate    float64
# dtype: object

# %%
# Statistic
bon_df.describe()
# Out:
#        Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# count    730.000000  730.000000   730.000000      730.000000
# mean       0.988342    3.036301     5.091781        7.933849
# std        0.151529    0.167394     0.306843        0.480240
# min        0.600000    2.510000     4.050000        6.490000
# 25%        0.900000    2.950000     4.900000        7.620000
# 50%        1.005000    3.050000     5.090000        7.910000
# 75%        1.070000    3.170000     5.280000        8.240000
# max        1.840000    3.360000     5.860000        9.190000

# %%
bon_df.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
# Task create dataframe that includes all rows of only the Funding Rate column.
# Task review by creating a line plot and histogram.
FndRt_df = bon_df.loc[:,"Funding Rate"]
FndRt_df
# Out:
# Date
# 2019-01-01    1.49
# 2019-01-02    1.84
# 2019-01-03    1.69
# 2019-01-04    1.57
# 2019-01-05    1.30
#               ...
# 2020-12-26    1.17
# 2020-12-27    1.20
# 2020-12-28    1.21
# 2020-12-29    1.20
# 2020-12-30    1.21
# Name: Funding Rate, Length: 730, dtype: float64

# %%
FndRt_df.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
FndRt_df.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# Task create dataframe only from year 2020.

# %%
yr2020_df = bon_df.loc["2020"]
yr2020_df
# Out:
#             Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# Date
# 2020-01-01          1.03        2.98         5.37            7.56
# 2020-01-02          1.05        3.00         5.34            7.73
# 2020-01-03          1.07        2.99         5.32            7.93
# 2020-01-04          1.09        2.98         5.28            7.96
# 2020-01-05          1.10        2.99         5.21            7.95
# ...                  ...         ...          ...             ...
# 2020-12-26          1.17        3.26         4.85            7.27
# 2020-12-27          1.20        3.26         4.86            7.35
# 2020-12-28          1.21        3.23         4.86            7.49
# 2020-12-29          1.20        3.19         4.84            7.58
# 2020-12-30          1.21        3.17         4.82            7.67
#
# [365 rows x 4 columns]

# %%
yr2020_df.describe()
# Out:
#        Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# count    365.000000  365.000000   365.000000      365.000000
# mean       1.005014    3.034630     4.987041        8.099945
# std        0.084469    0.197728     0.193423        0.440796
# min        0.780000    2.590000     4.570000        6.820000
# 25%        0.950000    2.870000     4.860000        7.770000
# 50%        1.020000    3.090000     4.980000        8.120000
# 75%        1.060000    3.190000     5.130000        8.420000
# max        1.220000    3.360000     5.450000        9.190000

# %%
yr2020_df.plot(kind="box")
# Out:
# <AxesSubplot: >

# %%
filter_high = yr2020_df["Funding Rate"] >= 1
fndhg_df = yr2020_df.loc[filter_high]
fndhg_df.head()
# Out:
#             Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# Date
# 2020-01-01          1.03        2.98         5.37            7.56
# 2020-01-02          1.05        3.00         5.34            7.73
# 2020-01-03          1.07        2.99         5.32            7.93
# 2020-01-04          1.09        2.98         5.28            7.96
# 2020-01-05          1.10        2.99         5.21            7.95

# %%
fndhg_df.describe()
# Out:
#        Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# count    223.000000  223.000000   223.000000      223.000000
# mean       1.058610    3.079103     4.937892        8.102466
# std        0.049886    0.186234     0.148799        0.455891
# min        1.000000    2.680000     4.590000        6.820000
# 25%        1.025000    2.930000     4.850000        7.845000
# 50%        1.050000    3.150000     4.930000        8.130000
# 75%        1.080000    3.230000     5.040000        8.405000
# max        1.220000    3.360000     5.370000        9.190000

# %%
filter_low = yr2020_df["Funding Rate"] <= 1
fndlw_df = yr2020_df.loc[filter_low]
fndlw_df.head()
# Out:
#             Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# Date
# 2020-01-12          1.00        3.10         5.15            8.00
# 2020-01-13          0.96        3.12         5.16            7.96
# 2020-01-14          0.95        3.13         5.23            7.96
# 2020-01-15          0.93        3.09         5.28            7.96
# 2020-01-16          0.91        3.06         5.30            8.05

# %%
fndlw_df.describe()
# Out:
#        Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# count    160.000000  160.000000   160.000000      160.000000
# mean       0.929750    2.981125     5.043687        8.103875
# std        0.055976    0.196766     0.230517        0.422441
# min        0.780000    2.590000     4.570000        6.860000
# 25%        0.890000    2.780000     4.897500        7.755000
# 50%        0.940000    3.040000     5.090000        8.130000
# 75%        0.980000    3.130000     5.230000        8.435000
# max        1.000000    3.300000     5.450000        8.960000

# %%
lowhgfnd_df = yr2020_df.loc[filter_high & filter_low]
lowhgfnd_df
# Out:
#             Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# Date
# 2020-01-12           1.0        3.10         5.15            8.00
# 2020-01-25           1.0        3.01         4.91            8.36
# 2020-02-26           1.0        3.19         4.89            8.58
# 2020-03-20           1.0        3.18         5.08            8.28
# 2020-03-21           1.0        3.17         5.06            8.17
# 2020-05-28           1.0        3.00         4.74            8.21
# 2020-05-29           1.0        2.98         4.78            8.16
# 2020-06-03           1.0        2.98         4.94            8.43
# 2020-06-29           1.0        3.18         5.17            7.83
# 2020-06-30           1.0        3.15         5.11            7.81
# 2020-07-29           1.0        2.68         5.03            7.40
# 2020-08-07           1.0        2.92         4.88            6.86
# 2020-10-21           1.0        3.11         4.69            8.48
# ...

# %%
lowhgfnd_df.describe()
# Out:
#        Funding Rate  Prime Rate  Retail Rate  Sub-prime Rate
# count          18.0   18.000000    18.000000       18.000000
# mean            1.0    3.110000     4.881667        8.166111
# std             0.0    0.157443     0.187593        0.467398
# min             1.0    2.680000     4.590000        6.860000
# 25%             1.0    3.002500     4.710000        8.040000
# 50%             1.0    3.160000     4.885000        8.245000
# 75%             1.0    3.235000     5.052500        8.467500
# max             1.0    3.290000     5.170000        8.790000

# %%
lowhgfnd_df.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
lowhgfnd_df.
