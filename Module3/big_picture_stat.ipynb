# %%
# Import all the modules associated with the pandas, pathlib library.
import pandas as pd
from pathlib import Path
import numpy as np

# %%
# Make the connection to the source file.
ret_csv = Path(r"C:\Users\admin\Desktop\FinTech\FinTech2022_Module3_Financial Analysis_Pandas\01-Summary_Statistics\returns.csv")

# %%
# Make Pandas read the CSV file.
# Create Pandas DataFrame.
ret_df = pd.read_csv(ret_csv)

# %%
# Take sample population from the source file.
ret_df.head()
# Out:
#    Unnamed: 0   Stock A   Stock B   Stock C
# 0  2020-01-06  2.061447  0.917560  0.416361
# 1  2020-01-07  1.542626  0.919384  1.757246
# 2  2020-01-08 -2.666572 -0.028768  0.962098
# 3  2020-01-09  3.169014  0.108129  1.665737
# 4  2020-01-10 -0.314594 -0.595625  0.534615

# %%
# Impostant in financial analysis: Summarization.
ret_df.describe()
# Out:
#         Stock A   Stock B   Stock C
# count  5.000000  5.000000  5.000000
# mean   0.758384  0.264136  1.067212
# std    2.291602  0.652999  0.623036
# min   -2.666572 -0.595625  0.416361
# 25%   -0.314594 -0.028768  0.534615
# 50%    1.542626  0.108129  0.962098
# 75%    2.061447  0.917560  1.665737
# max    3.169014  0.919384  1.757246

# %%
sales_data = pd.DataFrame({"prices": [1, 2, 3, 3, 5, 1]})
sales_data.plot()
# Out:
# <AxesSubplot: >

# %%
daily_returns = pd.DataFrame(
    np.random.randn(10, 2),
    index=pd.date_range('1/1/2020', periods=10),
    columns=["AAPL", "GOOG"])
daily_returns.describe()
# Out:
#             AAPL       GOOG
# count  10.000000  10.000000
# mean    0.099013  -0.194290
# std     0.617296   0.895654
# min    -0.754975  -1.931059
# 25%    -0.219688  -0.651640
# 50%    -0.013368   0.110072
# 75%     0.289355   0.510993
# max     1.309887   0.781792

# %%
daily_returns.plot()
# Out:
# <AxesSubplot: >

# %%
daily_returns.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>
